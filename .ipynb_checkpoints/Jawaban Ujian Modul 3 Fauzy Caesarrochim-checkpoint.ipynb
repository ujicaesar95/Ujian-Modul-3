# %% [markdown]
# ## 1. Import Libraries (pandas,numpy,matplotlib.pyplot,seaborn) and set %matplotlib inline

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Import Data creditcard.csv and show the top 5 data

# %%
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 3. Show the info of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# V24       284807 non-null float64
# V25       284807 non-null float64
# V26       284807 non-null float64
# V27       284807 non-null float64
# V28       284807 non-null float64
# Amount    284807 non-null float64
# Class     284807 non-null int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# V24       284807 non-null float64
# V25       284807 non-null float64
# V26       284807 non-null float64
# V27       284807 non-null float64
# V28       284807 non-null float64
# Amount    284807 non-null float64
# Class     284807 non-null int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# ## 4. Show the describe of the dataframe

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#            ...                 V21           V22           V23           V24  \
# count      ...        2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean       ...        1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std        ...        7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min        ...       -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%        ...       -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%        ...       -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%        ...        1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max        ...        2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#            ...                 V21           V22           V23           V24  \
# count      ...        2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean       ...        1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std        ...        7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min        ...       -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%        ...       -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%        ...       -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%        ...        1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max        ...        2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ## 5. Show info table of the DF like this

# %%
dfDescribe=pd.DataFrame(columns='dataFeatures dataType null nullPct unique uniqueSample'.split(),
                        data=[[col, df.dtypes[col], sum(df[col].isna()),round(100*sum(df[col].isna())/len(df[col]),2),df[col].nunique(),list(df[col].unique()[:2])]for col in df.columns])
                                                                  
dfDescribe
# Out:
#    dataFeatures dataType  null  nullPct  unique  \
# 0          Time  float64     0      0.0  124592
# 1            V1  float64     0      0.0  275663
# 2            V2  float64     0      0.0  275663
# 3            V3  float64     0      0.0  275663
# 4            V4  float64     0      0.0  275663
# 5            V5  float64     0      0.0  275663
# 6            V6  float64     0      0.0  275663
# 7            V7  float64     0      0.0  275663
# 8            V8  float64     0      0.0  275663
# 9            V9  float64     0      0.0  275663
# 10          V10  float64     0      0.0  275663
# 11          V11  float64     0      0.0  275663
# 12          V12  float64     0      0.0  275663
# 13          V13  float64     0      0.0  275663
# 14          V14  float64     0      0.0  275663
# 15          V15  float64     0      0.0  275663
# 16          V16  float64     0      0.0  275663
# 17          V17  float64     0      0.0  275663
# 18          V18  float64     0      0.0  275663
# 19          V19  float64     0      0.0  275663
# 20          V20  float64     0      0.0  275663
# 21          V21  float64     0      0.0  275663
# 22          V22  float64     0      0.0  275663
# 23          V23  float64     0      0.0  275663
# 24          V24  float64     0      0.0  275663
# 25          V25  float64     0      0.0  275663
# 26          V26  float64     0      0.0  275663
# 27          V27  float64     0      0.0  275663
# 28          V28  float64     0      0.0  275663
# 29       Amount  float64     0      0.0   32767
# 30        Class    int64     0      0.0       2
#
#                                    uniqueSample
# 0                                    [0.0, 1.0]
# 1        [-1.3598071336738, 1.1918571113148602]
# 2       [-0.0727811733098497, 0.26615071205963]
# 3          [2.53634673796914, 0.16648011335321]
# 4         [1.37815522427443, 0.448154078460911]
# 5    [-0.33832076994251803, 0.0600176492822243]
# 6      [0.462387777762292, -0.0823608088155687]
# 7      [0.239598554061257, -0.0788029833323113]
# 8      [0.0986979012610507, 0.0851016549148104]
# 9       [0.363786969611213, -0.255425128109186]
# 10   [0.0907941719789316, -0.16697441400461402]
# 11     [-0.551599533260813, 1.6127266610547901]
# 12       [-0.617800855762348, 1.06523531137287]
# 13       [-0.991389847235408, 0.48909501589608]
# 14   [-0.31116935369987897, -0.143772296441519]
# 15        [1.46817697209427, 0.635558093258208]
# 16    [-0.47040052525947795, 0.463917041022171]
# 17    [0.20797124192924202, -0.114804663102346]
# 18   [0.0257905801985591, -0.18336127012399397]
# 19    [0.403992960255733, -0.14578304132525902]
# 20     [0.251412098239705, -0.0690831352230203]
# 21     [-0.018306777944153, -0.225775248033138]
# 22     [0.277837575558899, -0.6386719527718511]
# 23    [-0.110473910188767, 0.10128802125323402]
# 24   [0.0669280749146731, -0.33984647552912706]
# 25     [0.12853935827352803, 0.167170404418143]
# 26      [-0.189114843888824, 0.125894532368176]
# 27  [0.13355837674038698, -0.00898309914322813]
# 28    [-0.0210530534538215, 0.0147241691924927]
# 29                               [149.62, 2.69]
# 30                                       [0, 1]

# %%
# Out:
#    dataFeatures dataType  null  nullPct  unique  \
# 0          Time  float64     0      0.0  124592
# 1            V1  float64     0      0.0  275663
# 2            V2  float64     0      0.0  275663
# 3            V3  float64     0      0.0  275663
# 4            V4  float64     0      0.0  275663
# 5            V5  float64     0      0.0  275663
# 6            V6  float64     0      0.0  275663
# 7            V7  float64     0      0.0  275663
# 8            V8  float64     0      0.0  275663
# 9            V9  float64     0      0.0  275663
# 10          V10  float64     0      0.0  275663
# 11          V11  float64     0      0.0  275663
# 12          V12  float64     0      0.0  275663
# 13          V13  float64     0      0.0  275663
# 14          V14  float64     0      0.0  275663
# 15          V15  float64     0      0.0  275663
# 16          V16  float64     0      0.0  275663
# 17          V17  float64     0      0.0  275663
# 18          V18  float64     0      0.0  275663
# 19          V19  float64     0      0.0  275663
# 20          V20  float64     0      0.0  275663
# 21          V21  float64     0      0.0  275663
# 22          V22  float64     0      0.0  275663
# 23          V23  float64     0      0.0  275663
# 24          V24  float64     0      0.0  275663
# 25          V25  float64     0      0.0  275663
# 26          V26  float64     0      0.0  275663
# 27          V27  float64     0      0.0  275663
# 28          V28  float64     0      0.0  275663
# 29       Amount  float64     0      0.0   32767
# 30        Class    int64     0      0.0       2
#
#                                    uniqueSample
# 0                           [165466.0, 37518.0]
# 1       [-1.56165865162217, -4.315483759010499]
# 2        [0.0846519393542383, 1.11200788961402]
# 3      [-0.30266404436512395, -1.7635668491357]
# 4      [0.0255533912428539, 0.0173969626810594]
# 5       [-0.947176872665042, 0.152654000967396]
# 6       [1.44189330621124, 0.30951574698730794]
# 7      [0.10698859687773599, 0.214072909522165]
# 8      [0.35499859453188504, 0.725531153255623]
# 9        [0.57890221210896, -0.364745566651037]
# 10        [-1.09604767696245, 1.53296715073124]
# 11      [0.270476906413186, -0.732585017759009]
# 12    [-0.45701230653574293, -1.28038092090679]
# 13   [-1.5840125401932998, 0.48655298643657796]
# 14     [-0.5529557106896981, -8.64045910049478]
# 15    [0.20512407419772302, -0.167887523045929]
# 16      [1.1198581755513302, 0.284039812016578]
# 17       [1.37284134763956, -0.357169801247661]
# 18     [-0.576134402576322, 0.9067851920675629]
# 19   [-0.0840343758215201, -0.9090851348996559]
# 20       [0.294654588892198, 0.560310549769586]
# 21    [-0.45086023203591397, 0.198278207786265]
# 22     [0.439266923613877, -0.8522241400742451]
# 23     [0.0108285422818712, -0.616717166351258]
# 24  [-0.47616486179760203, -0.6561402704448001]
# 25   [-0.44397073737884707, -0.420422537278077]
# 26  [0.19835636804016502, -0.11813969698122699]
# 27    [0.0260084857557669, -0.0694803180102379]
# 28      [-0.067782640620794, -0.25395695980223]
# 29                            [1201.93, 559.99]
# 30                                       [1, 0]

# %% [markdown]
# ## 6. Do Standard Scaler for all variable except the target

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(df)

scaled_data = scaler.transform(df)
scaled_data

dfScaled = pd.DataFrame(scaled_data, columns=df.columns)
dfScaled = dfScaled.drop('Class', axis=1)

dfScaled['Class'] = df['Class']
dfScaled.head()
# Out:
# E:\Anaconda\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# E:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1 -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2 -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3 -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4 -1.996541 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
#
#          V7        V8        V9  ...         V21       V22       V23  \
# 0  0.193679  0.082637  0.331128  ...   -0.024923  0.382854 -0.176911
# 1 -0.063700  0.071253 -0.232494  ...   -0.307377 -0.880077  0.162201
# 2  0.639776  0.207373 -1.378675  ...    0.337632  1.063358  1.456320
# 3  0.192071  0.316018 -1.262503  ...   -0.147443  0.007267 -0.304777
# 4  0.479302 -0.226510  0.744326  ...   -0.012839  1.100011 -0.220123
#
#         V24       V25       V26       V27       V28    Amount  Class
# 0  0.110507  0.246585 -0.392170  0.330892 -0.063781  0.244964      0
# 1 -0.561131  0.320694  0.261069 -0.022256  0.044608 -0.342475      0
# 2 -1.138092 -0.628537 -0.288447 -0.137137 -0.181021  1.160686      0
# 3 -1.941027  1.241904 -0.460217  0.155396  0.186189  0.140534      0
# 4  0.233250 -0.395202  1.041611  0.543620  0.651816 -0.073403      0
#
# [5 rows x 31 columns]

# %%
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1 -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2 -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3 -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4 -1.996541 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
#
#          V7        V8        V9  ...         V21       V22       V23  \
# 0  0.193679  0.082637  0.331128  ...   -0.024923  0.382854 -0.176911
# 1 -0.063700  0.071253 -0.232494  ...   -0.307377 -0.880077  0.162201
# 2  0.639776  0.207373 -1.378675  ...    0.337632  1.063358  1.456320
# 3  0.192071  0.316018 -1.262503  ...   -0.147443  0.007267 -0.304777
# 4  0.479302 -0.226510  0.744326  ...   -0.012839  1.100011 -0.220123
#
#         V24       V25       V26       V27       V28    Amount  Class
# 0  0.110507  0.246585 -0.392170  0.330892 -0.063781  0.244964      0
# 1 -0.561131  0.320694  0.261069 -0.022256  0.044608 -0.342475      0
# 2 -1.138092 -0.628537 -0.288447 -0.137137 -0.181021  1.160686      0
# 3 -1.941027  1.241904 -0.460217  0.155396  0.186189  0.140534      0
# 4  0.233250 -0.395202  1.041611  0.543620  0.651816 -0.073403      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 7. Do PCA for the features to make it only 10 features remaining

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=10)
pca.fit(dfScaled)

x_pca = pca.transform(dfScaled)

x_pca.shape
# Out:
# (284807, 10)

# %%
# Out:
# (284807, 10)

# %% [markdown]
# #### and go make the data dataframe results of the PCA like below

# %%
dfpca = pd.DataFrame(x_pca, columns=('Feature1 Feature2 Feature3 Feature4 Feature5 Feature6 Feature7 Feature8 Feature9 Feature10').split())
dfpca.head()
# Out:
#    Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 0  0.404803 -2.507639 -0.000243  0.060185  0.928924 -0.408857 -0.416912
# 1 -0.386912 -2.080927 -0.356203 -0.419050 -0.198094  0.576773  0.709062
# 2  1.879255 -2.546144  0.065307  2.903717  1.621987  0.549622 -0.591250
# 3  0.290697 -1.843581  0.159097  1.695574  1.633997  0.791416 -1.171524
# 4 -0.000100 -1.420567  0.223602  0.624794  1.454411 -0.508595 -0.485249
#
#    Feature8  Feature9  Feature10
# 0 -0.107619  0.793669   0.653607
# 1 -0.254212  0.022710   0.181870
# 2 -0.976624  1.073172   2.174727
# 3 -1.500437 -0.026060  -0.083218
# 4 -0.294475 -0.137014  -0.165464

# %%
# Out:
#    Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 0  0.462374 -2.506686  0.985430 -0.239791  0.478157  0.290669 -0.445321
# 1 -0.384371 -2.074072 -0.427201  0.752840  0.300410 -0.075940  0.076600
# 2  1.947514 -2.487909 -1.915677 -0.386594  1.454143 -0.052259  1.097327
# 3  0.352276 -1.811123 -0.375579 -1.466721  0.886097 -0.655393  0.282277
# 4  0.030544 -1.513528  0.133121 -0.402270  0.672664  0.040552 -1.054648
#
#    Feature8  Feature9  Feature10
# 0  0.169413 -0.575625   0.249432
# 1 -1.142084  0.468893   0.097866
# 2 -0.431775  0.194375   1.425578
# 3 -0.212690  0.926138  -1.362099
# 4  0.795551 -0.838480   1.124562

# %% [markdown]
# ## 8. Make target series dan show it value_counts in text and seaborn countplot

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="Class", data=df)

# %% [markdown]
# ## 9. Use K Fold (K=5,shuffle=True,random_state=42), every loop use RandomOverSampler for the training data, and then use GradientBoostingClassifier for the model

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score, matthews_corrcoef, f1_score
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, KFold, cross_validate
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.model_selection import train_test_split


data = dfpca
target = df['Class']

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3, random_state=101)

# %%
import imblearn
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=101)
X_ros, y_ros = ros.fit_resample(X_train,y_train)
pd.Series(y_ros).value_counts()
# Out:
# 1    227459
# 0    227459
# dtype: int64

# %%
def calc_train_error(X_train, y_train, model):
    predictions = model.predict(X_train)
    predictProba = model.predict_proba(X_train)
    matt = matthews_corrcoef(y_train, predictions)
    f1 = f1_score(y_train, predictions, average='macro')
    report = classification_report(y_train, predictions)
    roc_auc = roc_auc_score(y_train, predictProba[:,1])
    accuracy = accuracy_score(y_train, predictions)
    confMatrix = confusion_matrix(y_train, predictions)
    return {
        'report' : report,
        'matthews' : matt,
        'f1' : f1,
        'roc' : roc_auc,
        'accuracy' : accuracy,
        'confusion' : confMatrix
    }

def calc_validation_error(X_test, y_test, model):
    predictions = model.predict(X_test)
    predictProba = model.predict_proba(X_test)
    matt = matthews_corrcoef(y_test, predictions)
    f1 = f1_score(y_test, predictions, average='macro')
    report = classification_report(y_test, predictions)
    roc_auc = roc_auc_score(y_test, predictProba[:,1])
    accuracy = accuracy_score(y_test, predictions)
    confMatrix = confusion_matrix(y_test, predictions)
    return {
        'report' : report,
        'matthews' : matt,
        'f1' : f1,
        'roc' : roc_auc,
        'accuracy' : accuracy,
        'confusion' : confMatrix
    }

def calc_metrics(X_train, y_train, X_test, y_test, model) :
    model.fit(X_train, y_train)
    train_error = calc_train_error(X_train, y_train, model)
    validation_error = calc_validation_error(X_test, y_test, model)
    return train_error, validation_error

# %%
K = 5 
kf = KFold(n_splits=K, shuffle=True, random_state=42)
for train_index, test_index in kf.split(data,target) :
    print(train_index)
    print(test_index)
    print(len(train_index))
    print(len(test_index))
    print(data.iloc[train_index].head())
# Out:
# [     1      2      3 ... 284804 284805 284806]
# [     0      6     11 ... 284795 284798 284803]
# 227845
# 56962
#    Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 1 -0.386912 -2.080927 -0.356203 -0.419050 -0.198094  0.576773  0.709062
# 2  1.879255 -2.546144  0.065307  2.903717  1.621987  0.549622 -0.591250
# 3  0.290697 -1.843581  0.159097  1.695574  1.633997  0.791416 -1.171524
# 4 -0.000100 -1.420567  0.223602  0.624794  1.454411 -0.508595 -0.485249
# 5 -0.361124 -2.076387 -0.292210 -0.807089  0.335535  0.811361 -0.019016
#
#    Feature8  Feature9  Feature10
# 1 -0.254212  0.022710   0.181870
# 2 -0.976624  1.073172   2.174727
# 3 -1.500437 -0.026060  -0.083218
# 4 -0.294475 -0.137014  -0.165464
# 5  0.004535  0.408211   0.028971
# [     0      2      3 ... 284802 284803 284805]
# [     1      4     30 ... 284793 284804 284806]
# 227845
# 56962
#    Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 0  0.404803 -2.507639 -0.000243  0.060185  0.928924 -0.408857 -0.416912
# 2  1.879255 -2.546144  0.065307  2.903717  1.621987  0.549622 -0.591250
# 3  0.290697 -1.843581  0.159097  1.695574  1.633997  0.791416 -1.171524
# 5 -0.361124 -2.076387 -0.292210 -0.807089  0.335535  0.811361 -0.019016
# 6 -0.408479 -1.566238  0.134969 -0.396363 -0.352049 -0.762677  0.215745
#
#    Feature8  Feature9  Feature10
# 0 -0.107619  0.793669   0.653607
# 2 -0.976624  1.073172   2.174727
# 3 -1.500437 -0.026060  -0.083218
# 5  0.004535  0.408211   0.028971
# 6 -0.675579  0.098166   0.883420
# [     0      1      2 ... 284804 284805 284806]
# [     3     20     21 ... 284781 284783 284799]
# 227846
# 56961
#    Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 0  0.404803 -2.507639 -0.000243  0.060185  0.928924 -0.408857 -0.416912
# 1 -0.386912 -2.080927 -0.356203 -0.419050 -0.198094  0.576773  0.709062
# 2  1.879255 -2.546144  0.065307  2.903717  1.621987  0.549622 -0.591250
# 4 -0.000100 -1.420567  0.223602  0.624794  1.454411 -0.508595 -0.485249
# 5 -0.361124 -2.076387 -0.292210 -0.807089  0.335535  0.811361 -0.019016
#
#    Feature8  Feature9  Feature10
# 0 -0.107619  0.793669   0.653607
# 1 -0.254212  0.022710   0.181870
# 2 -0.976624  1.073172   2.174727
# 4 -0.294475 -0.137014  -0.165464
# 5  0.004535  0.408211   0.028971
# [     0      1      3 ... 284803 284804 284806]
# [     2      7      8 ... 284796 284801 284805]
# 227846
# 56961
#    Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 0  0.404803 -2.507639 -0.000243  0.060185  0.928924 -0.408857 -0.416912
# 1 -0.386912 -2.080927 -0.356203 -0.419050 -0.198094  0.576773  0.709062
# 3  0.290697 -1.843581  0.159097  1.695574  1.633997  0.791416 -1.171524
# 4 -0.000100 -1.420567  0.223602  0.624794  1.454411 -0.508595 -0.485249
# 5 -0.361124 -2.076387 -0.292210 -0.807089  0.335535  0.811361 -0.019016
#
#    Feature8  Feature9  Feature10
# 0 -0.107619  0.793669   0.653607
# 1 -0.254212  0.022710   0.181870
# 3 -1.500437 -0.026060  -0.083218
# 4 -0.294475 -0.137014  -0.165464
# 5  0.004535  0.408211   0.028971
# [     0      1      2 ... 284804 284805 284806]
# [     5      9     10 ... 284797 284800 284802]
# 227846
# 56961
#    Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 0  0.404803 -2.507639 -0.000243  0.060185  0.928924 -0.408857 -0.416912
# 1 -0.386912 -2.080927 -0.356203 -0.419050 -0.198094  0.576773  0.709062
# 2  1.879255 -2.546144  0.065307  2.903717  1.621987  0.549622 -0.591250
# 3  0.290697 -1.843581  0.159097  1.695574  1.633997  0.791416 -1.171524
# 4 -0.000100 -1.420567  0.223602  0.624794  1.454411 -0.508595 -0.485249
#
#    Feature8  Feature9  Feature10
# 0 -0.107619  0.793669   0.653607
# 1 -0.254212  0.022710   0.181870
# 2 -0.976624  1.073172   2.174727
# 3 -1.500437 -0.026060  -0.083218
# 4 -0.294475 -0.137014  -0.165464

# %%
train_errors = []
validation_errors = []

for train_index, test_index in kf.split(data, target):
    X_train, X_test = data.iloc[train_index], data.iloc[test_index]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]
    
    print(len(X_test), (len(X_train) + len(X_test)))
    
    gbr = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1)
    gbr.fit(X_ros,y_ros)
    
    train_error, test_error = calc_metrics(X_train, y_train, X_test, y_test, gbr)
    
    train_errors.append(train_error)
    validation_errors.append(test_error)
# Out:
# 56962 284807
# 56962 284807
# 56961 284807
# 56961 284807
# 56961 284807

# %% [markdown]
# ## 10. Print the Model Evaluation like below from the K Fold

# %%
for i, train_error, val_error in zip(range(1,6,1), train_errors, validation_errors):
    print('Accuracy train '+ str(i) + ':' + str(train_error['accuracy']))
    print('Accuracy test '+ str(i) + ':' + str(val_error['accuracy']))
    print('ROC AUC train '+ str(i) + ':' + str(train_error['roc']))
    print('ROC AUC test '+ str(i) + ':' + str(val_error['roc']))
    print('F1 Score train '+ str(i) + ':' + str(train_error['f1']))
    print('F1 Score test '+ str(i) + ':' + str(val_error['f1']))
    print('Matthews Corr Coef train '+ str(i) + ':' + str(train_error['matthews']))
    print('Matthews Corr Coef test '+ str(i) + ':' + str(val_error['matthews']))
   
    print('\n')
# Out:
# Accuracy train 1:0.998990541815708
# Accuracy test 1:0.9988237772550121
# ROC AUC train 1:0.5761199204683948
# ROC AUC test 1:0.5173299271875321
# F1 Score train 1:0.797992933423381
# F1 Score test 1:0.7551800428242832
# Matthews Corr Coef train 1:0.6452230877537279
# Matthews Corr Coef test 1:0.5657335936473178
#
#
# Accuracy train 2:0.9990914876341372
# Accuracy test 2:0.9989291106351603
# ROC AUC train 2:0.6549617539006809
# ROC AUC test 2:0.5468327794287456
# F1 Score train 2:0.8325673933342695
# F1 Score test 2:0.7771042180937504
# Matthews Corr Coef train 2:0.694939222487008
# Matthews Corr Coef test 2:0.5936310518094321
#
#
# Accuracy train 3:0.9993197159484916
# Accuracy test 3:0.9990870946788153
# ROC AUC train 3:0.7914710705540511
# ROC AUC test 3:0.6791726440922058
# F1 Score train 3:0.8839851348436412
# F1 Score test 3:0.8216892890235656
# Matthews Corr Coef train 3:0.7817895600286461
# Matthews Corr Coef test 3:0.6748717719834281
#
#
# Accuracy train 4:0.9990256576810653
# Accuracy test 4:0.9990870946788153
# ROC AUC train 4:0.577837143920039
# ROC AUC test 4:0.638362157531265
# F1 Score train 4:0.8077145825724368
# F1 Score test 4:0.8309402959040819
# Matthews Corr Coef train 4:0.65792805135069
# Matthews Corr Coef test 4:0.6967196627045154
#
#
# Accuracy train 5:0.9990300466104298
# Accuracy test 5:0.9989993153210092
# ROC AUC train 5:0.614592142812051
# ROC AUC test 5:0.607665145698071
# F1 Score train 5:0.8027875157888275
# F1 Score test 5:0.8205041961615334
# Matthews Corr Coef train 5:0.6547841824365372
# Matthews Corr Coef test 5:0.6769191036804841

# %%
dfModelEval =pd.DataFrame(columns=['Train Accuracy', 'Test Accuracy', 'Train ROC AUC', 'Test ROC AUC', 'Train F1 Score',
                                   'Test F1 Score', 'Train Matthews Corr Coef', 'Test Matthews Corr Coef'], 
                          data=[[train_error['accuracy'], val_error['accuracy'], train_error['roc'], val_error['roc'] , 
                                 train_error['f1'] , val_error['f1'], train_error['matthews'], val_error['matthews'] ]for i, train_error, val_error in zip(range(1,6,1), train_errors, validation_errors)])

dfModelEval
# Out:
#    Train Accuracy  Test Accuracy  Train ROC AUC  Test ROC AUC  Train F1 Score  \
# 0        0.998991       0.998824       0.576120      0.517330        0.797993
# 1        0.999091       0.998929       0.654962      0.546833        0.832567
# 2        0.999320       0.999087       0.791471      0.679173        0.883985
# 3        0.999026       0.999087       0.577837      0.638362        0.807715
# 4        0.999030       0.998999       0.614592      0.607665        0.802788
#
#    Test F1 Score  Train Matthews Corr Coef  Test Matthews Corr Coef
# 0       0.755180                  0.645223                 0.565734
# 1       0.777104                  0.694939                 0.593631
# 2       0.821689                  0.781790                 0.674872
# 3       0.830940                  0.657928                 0.696720
# 4       0.820504                  0.654784                 0.676919

# %%
# Out:
#    Train Accuracy  Test Accuracy  Train ROC AUC  Test ROC AUC  Train F1 Score  \
# 0        0.980633       0.988255       0.998365      0.970186        0.980632
# 1        0.979219       0.986851       0.997770      0.967743        0.979218
# 2        0.982528       0.990327       0.998887      0.933819        0.982527
# 3        0.972746       0.989098       0.998567      0.971217        0.972739
# 4        0.980722       0.986271       0.997832      0.968820        0.980721
#
#    Test F1 Score  Train Matthews Corr Coef  Test Matthews Corr Coef
# 0       0.598353                  0.961398                 0.313005
# 1       0.585600                  0.958571                 0.291167
# 2       0.604557                  0.965163                 0.310282
# 3       0.604714                  0.946017                 0.319572
# 4       0.594275                  0.961514                 0.312236

# %%
print('Accuracy train :'  + str(dfModelEval['Train Accuracy'].mean()))
print('Accuracy test : ' +  str(dfModelEval['Test Accuracy'].mean()))
print('ROC AUC train : ' +  str(dfModelEval['Train ROC AUC'].mean()))
print('ROC AUC test : '  + str(dfModelEval['Test ROC AUC'].mean()))
# Out:
# Accuracy train :0.9990914899379664
# Accuracy test : 0.9989852785137623
# ROC AUC train : 0.6429964063310434
# ROC AUC test : 0.597872530787564

# %%
# Out:
# Avg Accuracy Train : 0.9791696887616986
# Avg Accuracy Validation : 0.9881604076255293
# Avg ROC AUC Train : 0.9982841805609599
# Avg ROC AUC Validation : 0.9623571124081577

# %% [markdown]
# #### Training Errors Classification Reports

# %%
for i, train_error, val_error in zip(range(1,6,1), train_errors, validation_errors):
    print('report train '+ str(i) + ':')
    print(str(train_error['report']))
    print('\n')
# Out:
# report train 1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       0.97      0.43      0.60       394
#
#    micro avg       1.00      1.00      1.00    227845
#    macro avg       0.98      0.72      0.80    227845
# weighted avg       1.00      1.00      1.00    227845
#
#
#
# report train 2:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227446
#            1       0.94      0.52      0.67       399
#
#    micro avg       1.00      1.00      1.00    227845
#    macro avg       0.97      0.76      0.83    227845
# weighted avg       1.00      1.00      1.00    227845
#
#
#
# report train 3:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227449
#            1       0.94      0.65      0.77       397
#
#    micro avg       1.00      1.00      1.00    227846
#    macro avg       0.97      0.82      0.88    227846
# weighted avg       1.00      1.00      1.00    227846
#
#
#
# report train 4:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227455
#            1       0.95      0.46      0.62       391
#
#    micro avg       1.00      1.00      1.00    227846
#    macro avg       0.98      0.73      0.81    227846
# weighted avg       1.00      1.00      1.00    227846
#
#
#
# report train 5:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227459
#            1       0.98      0.44      0.61       387
#
#    micro avg       1.00      1.00      1.00    227846
#    macro avg       0.99      0.72      0.80    227846
# weighted avg       1.00      1.00      1.00    227846

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98    227451
#            1       0.99      0.97      0.98    227451
#
#    micro avg       0.98      0.98      0.98    454902
#    macro avg       0.98      0.98      0.98    454902
# weighted avg       0.98      0.98      0.98    454902
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98    227446
#            1       0.99      0.97      0.98    227446
#
#    micro avg       0.98      0.98      0.98    454892
#    macro avg       0.98      0.98      0.98    454892
# weighted avg       0.98      0.98      0.98    454892
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98    227449
#            1       0.99      0.98      0.98    227449
#
#    micro avg       0.98      0.98      0.98    454898
#    macro avg       0.98      0.98      0.98    454898
# weighted avg       0.98      0.98      0.98    454898
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97    227455
#            1       0.99      0.96      0.97    227455
#
#    micro avg       0.97      0.97      0.97    454910
#    macro avg       0.97      0.97      0.97    454910
# weighted avg       0.97      0.97      0.97    454910
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98    227459
#            1       0.99      0.97      0.98    227459
#
#    micro avg       0.98      0.98      0.98    454918
#    macro avg       0.98      0.98      0.98    454918
# weighted avg       0.98      0.98      0.98    454918

# %% [markdown]
# #### Validation Errors Classification Reports

# %%
for i, train_error, val_error in zip(range(1,6,1), train_errors, validation_errors):
    print('report test '+ str(i) + ':')
    print(str(val_error['report']))
    print('\n')
# Out:
# report test 1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.90      0.36      0.51        98
#
#    micro avg       1.00      1.00      1.00     56962
#    macro avg       0.95      0.68      0.76     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
#
# report test 2:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56869
#            1       0.86      0.41      0.55        93
#
#    micro avg       1.00      1.00      1.00     56962
#    macro avg       0.93      0.70      0.78     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
#
# report test 3:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56866
#            1       0.92      0.49      0.64        95
#
#    micro avg       1.00      1.00      1.00     56961
#    macro avg       0.96      0.75      0.82     56961
# weighted avg       1.00      1.00      1.00     56961
#
#
#
# report test 4:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56860
#            1       0.96      0.50      0.66       101
#
#    micro avg       1.00      1.00      1.00     56961
#    macro avg       0.98      0.75      0.83     56961
# weighted avg       1.00      1.00      1.00     56961
#
#
#
# report test 5:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56856
#            1       0.94      0.49      0.64       105
#
#    micro avg       1.00      1.00      1.00     56961
#    macro avg       0.97      0.74      0.82     56961
# weighted avg       1.00      1.00      1.00     56961

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56864
#            1       0.11      0.87      0.20        98
#
#    micro avg       0.99      0.99      0.99     56962
#    macro avg       0.56      0.93      0.60     56962
# weighted avg       1.00      0.99      0.99     56962
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56869
#            1       0.10      0.87      0.18        93
#
#    micro avg       0.99      0.99      0.99     56962
#    macro avg       0.55      0.93      0.59     56962
# weighted avg       1.00      0.99      0.99     56962
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56866
#            1       0.12      0.79      0.21        95
#
#    micro avg       0.99      0.99      0.99     56961
#    macro avg       0.56      0.89      0.60     56961
# weighted avg       1.00      0.99      0.99     56961
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56860
#            1       0.12      0.84      0.21       101
#
#    micro avg       0.99      0.99      0.99     56961
#    macro avg       0.56      0.92      0.60     56961
# weighted avg       1.00      0.99      0.99     56961
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56856
#            1       0.11      0.90      0.20       105
#
#    micro avg       0.99      0.99      0.99     56961
#    macro avg       0.55      0.95      0.59     56961
# weighted avg       1.00      0.99      0.99     56961

# %% [markdown]
# ### Print Features Importance

# %%
coef1 = pd.Series(gbr.feature_importances_, data.columns).sort_values(ascending = False).head(10)
coef1.plot(kind='bar', title='Feature Importances')

# %% [markdown]
# ## Goodluck Guys! Salam Bertasbih!
